# %% [markdown]
# ### Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### ✅ Step 1: Set Up Git Configuration (Run this only once)

# %%
# !git config --global user.name "suwickramanayaka"
# !git config --global user.email "suwickramanayaka@gmail.com"  # Replace with your GitHub email

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# !sudo apt-get install git-lfs
# !git lfs install
# Out:
# Detected operating system as Ubuntu/jammy.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Detected apt version as 2.4.13
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... Packagecloud gpg key imported to /etc/apt/keyrings/github_git-lfs-archive-keyring.gpg
# done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be upgraded:
#   git-lfs
# 1 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.
# Need to get 8,489 kB of archives.
# After this operation, 7,671 kB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu jammy/main amd64 git-lfs amd64 3.6.1 [8,489 kB]
# Fetched 8,489 kB in 0s (26.5 MB/s)
# ...

# %% [markdown]
# ### ✅ Step 3: Clone Your GitHub Repo into Colab

# %%
# !git clone https://suwickramanayaka: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@github.com/suwickramanayaka/FYP-Model.git
# Out:
# Cloning into 'FYP-Model'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.

# %% [markdown]
# ### Copy your project into the cloned repo

# %%
import shutil

# Define source (your project folder) and destination (the cloned GitHub repo)
src_folder = "/content/drive/MyDrive/Colab Notebooks/FYP_Model_NEW"
dst_folder = "/content/FYP-Model"

# Copy entire project to repo folder (excluding large folders)
shutil.copytree(src_folder, dst_folder, dirs_exist_ok=True)
print("✅ Project copied to repo folder.")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-6-2bd135db5701> in <cell line: 0>()
#       6
#       7 # Copy entire project to repo folder (excluding large folders)
# ----> 8 shutil.copytree(src_folder, dst_folder, dirs_exist_ok=True)
#       9 print("✅ Project copied to repo folder.")
#
# /usr/lib/python3.11/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     571     with os.scandir(src) as itr:
#     572         entries = list(itr)
# --> 573     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     574                      ignore=ignore, copy_function=copy_function,
#     575                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# ...

# %% [markdown]
# ### Step 3: Create .gitignore to exclude large or private files

# %%
gitignore_path = "/content/FYP-Model/.gitignore"

with open(gitignore_path, "w") as f:
    f.write("""
# Ignore datasets, model weights, logs, and Colab-specific files
__pycache__/
.ipynb_checkpoints/
annotations.zip
train.zip
val.zip
test.zip
runs/
outputs/yolov8m_COCO_FYP/
datasets/
""")

print("✅ .gitignore created.")

# %% [markdown]
# ### 🔹 Step 4: Commit and push to GitHub

# %%
# %cd /content/FYP-Model

# !git config user.email "suwickramanayaka@gmail.com"   # Replace with your GitHub email
# !git config user.name "suwickramanayaka"

# !git add .
# !git commit -m "Initial push: YOLOv8 model development completed ✅"
# !git push origin main
